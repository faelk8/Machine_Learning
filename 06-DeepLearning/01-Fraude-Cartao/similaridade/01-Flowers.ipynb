# %%
import os 
import pandas as pd
import numpy as np 

import gc
gc.collect()
# Out:
# 0

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# !pip install fastai==1.0.52
import fastai

from fastai import *
from fastai.vision import *

# from torchvision.models import *
# import pretrainedmodels

from utils import *
import sys

from fastai.callbacks.hooks import *

from fastai.callbacks.tracker import EarlyStoppingCallback
from fastai.callbacks.tracker import SaveModelCallback
# Out:
# WARNING: Skipping /home/rafael/anaconda3/lib/python3.11/site-packages/colorama-0.4.6.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/rafael/anaconda3/lib/python3.11/site-packages/colorama-0.4.6.dist-info due to invalid metadata entry 'name'
# Collecting fastai==1.0.52
#   Downloading fastai-1.0.52-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: bottleneck in /home/rafael/anaconda3/lib/python3.11/site-packages (from fastai==1.0.52) (1.3.7)
# Collecting fastprogress>=0.1.19 (from fastai==1.0.52)
#   Downloading fastprogress-1.0.3-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: beautifulsoup4 in /home/rafael/anaconda3/lib/python3.11/site-packages (from fastai==1.0.52) (4.12.2)
# Requirement already satisfied: matplotlib in /home/rafael/anaconda3/lib/python3.11/site-packages (from fastai==1.0.52) (3.8.0)
# Requirement already satisfied: numexpr in /home/rafael/anaconda3/lib/python3.11/site-packages (from fastai==1.0.52) (2.8.7)
# Requirement already satisfied: numpy>=1.15 in /home/rafael/anaconda3/lib/python3.11/site-packages (from fastai==1.0.52) (1.26.4)
# Collecting nvidia-ml-py3 (from fastai==1.0.52)
#   Downloading nvidia-ml-py3-7.352.0.tar.gz (19 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas in /home/rafael/anaconda3/lib/python3.11/site-packages (from fastai==1.0.52) (2.1.4)
# Requirement already satisfied: packaging in /home/rafael/anaconda3/lib/python3.11/site-packages (from fastai==1.0.52) (23.2)
# Requirement already satisfied: Pillow in /home/rafael/anaconda3/lib/python3.11/site-packages (from fastai==1.0.52) (10.2.0)
# Requirement already satisfied: pyyaml in /home/rafael/anaconda3/lib/python3.11/site-packages (from fastai==1.0.52) (6.0.1)
# Requirement already satisfied: requests in /home/rafael/anaconda3/lib/python3.11/site-packages (from fastai==1.0.52) (2.31.0)
# Requirement already satisfied: scipy in /home/rafael/anaconda3/lib/python3.11/site-packages (from fastai==1.0.52) (1.12.0)
# Collecting torch>=1.0.0 (from fastai==1.0.52)
#   Downloading torch-2.2.2-cp311-cp311-manylinux1_x86_64.whl.metadata (25 kB)
# Collecting typing (from fastai==1.0.52)
#   Downloading typing-3.7.4.3.tar.gz (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 3.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting spacy>=2.0.18 (from fastai==1.0.52)
#   Downloading spacy-3.7.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (27 kB)
# Collecting torchvision (from fastai==1.0.52)
#   Downloading torchvision-0.17.2-cp311-cp311-manylinux1_x86_64.whl.metadata (6.6 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.11 (from spacy>=2.0.18->fastai==1.0.52)
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0 (from spacy>=2.0.18->fastai==1.0.52)
#   Downloading spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy>=2.0.18->fastai==1.0.52)
#   Downloading murmurhash-1.0.10-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.0 kB)
# Collecting cymem<2.1.0,>=2.0.2 (from spacy>=2.0.18->fastai==1.0.52)
#   Downloading cymem-2.0.8-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.4 kB)
# Collecting preshed<3.1.0,>=3.0.2 (from spacy>=2.0.18->fastai==1.0.52)
#   Downloading preshed-3.0.9-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.2 kB)
# Collecting thinc<8.3.0,>=8.2.2 (from spacy>=2.0.18->fastai==1.0.52)
#   Downloading thinc-8.2.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (15 kB)
# Collecting wasabi<1.2.0,>=0.9.1 (from spacy>=2.0.18->fastai==1.0.52)
#   Downloading wasabi-1.1.2-py3-none-any.whl.metadata (28 kB)
# Collecting srsly<3.0.0,>=2.4.3 (from spacy>=2.0.18->fastai==1.0.52)
#   Downloading srsly-2.4.8-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Collecting catalogue<2.1.0,>=2.0.6 (from spacy>=2.0.18->fastai==1.0.52)
#   Downloading catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# Collecting weasel<0.4.0,>=0.1.0 (from spacy>=2.0.18->fastai==1.0.52)
#   Downloading weasel-0.3.4-py3-none-any.whl.metadata (4.7 kB)
# Collecting typer<0.10.0,>=0.3.0 (from spacy>=2.0.18->fastai==1.0.52)
#   Downloading typer-0.9.4-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /home/rafael/anaconda3/lib/python3.11/site-packages (from spacy>=2.0.18->fastai==1.0.52) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/rafael/anaconda3/lib/python3.11/site-packages (from spacy>=2.0.18->fastai==1.0.52) (4.65.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /home/rafael/anaconda3/lib/python3.11/site-packages (from spacy>=2.0.18->fastai==1.0.52) (2.5.3)
# Requirement already satisfied: jinja2 in /home/rafael/anaconda3/lib/python3.11/site-packages (from spacy>=2.0.18->fastai==1.0.52) (3.1.3)
# Requirement already satisfied: setuptools in /home/rafael/anaconda3/lib/python3.11/site-packages (from spacy>=2.0.18->fastai==1.0.52) (68.2.2)
# Collecting langcodes<4.0.0,>=3.2.0 (from spacy>=2.0.18->fastai==1.0.52)
#   Downloading langcodes-3.3.0-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/rafael/anaconda3/lib/python3.11/site-packages (from requests->fastai==1.0.52) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/rafael/anaconda3/lib/python3.11/site-packages (from requests->fastai==1.0.52) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/rafael/anaconda3/lib/python3.11/site-packages (from requests->fastai==1.0.52) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /home/rafael/anaconda3/lib/python3.11/site-packages (from requests->fastai==1.0.52) (2023.11.17)
# Requirement already satisfied: filelock in /home/rafael/anaconda3/lib/python3.11/site-packages (from torch>=1.0.0->fastai==1.0.52) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/rafael/anaconda3/lib/python3.11/site-packages (from torch>=1.0.0->fastai==1.0.52) (4.9.0)
# Requirement already satisfied: sympy in /home/rafael/anaconda3/lib/python3.11/site-packages (from torch>=1.0.0->fastai==1.0.52) (1.12)
# Requirement already satisfied: networkx in /home/rafael/anaconda3/lib/python3.11/site-packages (from torch>=1.0.0->fastai==1.0.52) (3.1)
# Requirement already satisfied: fsspec in /home/rafael/anaconda3/lib/python3.11/site-packages (from torch>=1.0.0->fastai==1.0.52) (2023.12.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.0.0->fastai==1.0.52)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.0.0->fastai==1.0.52)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.0.0->fastai==1.0.52)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.0.0->fastai==1.0.52)
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.0.0->fastai==1.0.52)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.0.0->fastai==1.0.52)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.0.0->fastai==1.0.52)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.0.0->fastai==1.0.52)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.0.0->fastai==1.0.52)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.19.3 (from torch>=1.0.0->fastai==1.0.52)
#   Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.0.0->fastai==1.0.52)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Collecting triton==2.2.0 (from torch>=1.0.0->fastai==1.0.52)
#   Downloading triton-2.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.4 kB)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.0.0->fastai==1.0.52)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: soupsieve>1.2 in /home/rafael/anaconda3/lib/python3.11/site-packages (from beautifulsoup4->fastai==1.0.52) (2.5)
# Requirement already satisfied: contourpy>=1.0.1 in /home/rafael/anaconda3/lib/python3.11/site-packages (from matplotlib->fastai==1.0.52) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/rafael/anaconda3/lib/python3.11/site-packages (from matplotlib->fastai==1.0.52) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/rafael/anaconda3/lib/python3.11/site-packages (from matplotlib->fastai==1.0.52) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/rafael/anaconda3/lib/python3.11/site-packages (from matplotlib->fastai==1.0.52) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/rafael/anaconda3/lib/python3.11/site-packages (from matplotlib->fastai==1.0.52) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/rafael/anaconda3/lib/python3.11/site-packages (from matplotlib->fastai==1.0.52) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/rafael/anaconda3/lib/python3.11/site-packages (from pandas->fastai==1.0.52) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/rafael/anaconda3/lib/python3.11/site-packages (from pandas->fastai==1.0.52) (2023.4)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/rafael/anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=2.0.18->fastai==1.0.52) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in /home/rafael/anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=2.0.18->fastai==1.0.52) (2.14.6)
# Requirement already satisfied: six>=1.5 in /home/rafael/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->fastai==1.0.52) (1.16.0)
# Collecting blis<0.8.0,>=0.7.8 (from thinc<8.3.0,>=8.2.2->spacy>=2.0.18->fastai==1.0.52)
#   Downloading blis-0.7.11-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.4 kB)
# Collecting confection<1.0.0,>=0.0.1 (from thinc<8.3.0,>=8.2.2->spacy>=2.0.18->fastai==1.0.52)
#   Downloading confection-0.1.4-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/rafael/anaconda3/lib/python3.11/site-packages (from typer<0.10.0,>=0.3.0->spacy>=2.0.18->fastai==1.0.52) (8.1.7)
# Collecting cloudpathlib<0.17.0,>=0.7.0 (from weasel<0.4.0,>=0.1.0->spacy>=2.0.18->fastai==1.0.52)
#   Downloading cloudpathlib-0.16.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/rafael/anaconda3/lib/python3.11/site-packages (from jinja2->spacy>=2.0.18->fastai==1.0.52) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /home/rafael/anaconda3/lib/python3.11/site-packages (from sympy->torch>=1.0.0->fastai==1.0.52) (1.3.0)
# Downloading fastai-1.0.52-py3-none-any.whl (219 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.0/220.0 kB 10.6 MB/s eta 0:00:00
# Downloading fastprogress-1.0.3-py3-none-any.whl (12 kB)
# Downloading spacy-3.7.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 46.3 MB/s eta 0:00:0000:0100:01
# Downloading torch-2.2.2-cp311-cp311-manylinux1_x86_64.whl (755.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.6/755.6 MB 5.6 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 9.2 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 40.4 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 39.7 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 39.7 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 6.4 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 18.4 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 20.1 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 22.1 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 18.5 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 18.4 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 38.2 MB/s eta 0:00:00
# Downloading triton-2.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (167.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.9/167.9 MB 18.8 MB/s eta 0:00:0000:0100:01
# Downloading torchvision-0.17.2-cp311-cp311-manylinux1_x86_64.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 35.3 MB/s eta 0:00:00a 0:00:01
# Downloading catalogue-2.0.10-py3-none-any.whl (17 kB)
# Downloading cymem-2.0.8-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.3/46.3 kB 17.0 MB/s eta 0:00:00
# Downloading langcodes-3.3.0-py3-none-any.whl (181 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.6/181.6 kB 46.0 MB/s eta 0:00:00
# Downloading murmurhash-1.0.10-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29 kB)
# Downloading preshed-3.0.9-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (157 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 157.2/157.2 kB 35.6 MB/s eta 0:00:00
# Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Downloading spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Downloading srsly-2.4.8-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (490 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 490.9/490.9 kB 38.6 MB/s eta 0:00:00
# Downloading thinc-8.2.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (920 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 920.1/920.1 kB 34.2 MB/s eta 0:00:00
# Downloading typer-0.9.4-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 18.6 MB/s eta 0:00:00
# Downloading wasabi-1.1.2-py3-none-any.whl (27 kB)
# Downloading weasel-0.3.4-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 23.7 MB/s eta 0:00:00
# Downloading blis-0.7.11-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 34.0 MB/s eta 0:00:0000:010:01
# Downloading cloudpathlib-0.16.0-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.0/45.0 kB 17.5 MB/s eta 0:00:00
# Downloading confection-0.1.4-py3-none-any.whl (35 kB)
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 35.1 MB/s eta 0:00:0000:0100:01
# Building wheels for collected packages: nvidia-ml-py3, typing
#   Building wheel for nvidia-ml-py3 (setup.py) ... done
#   Created wheel for nvidia-ml-py3: filename=nvidia_ml_py3-7.352.0-py3-none-any.whl size=19171 sha256=ca4b5a4b3313bc07b620019084af18105492c5e7192ba6526a4ce3539c04db87
#   Stored in directory: /home/rafael/.cache/pip/wheels/47/50/9e/29dc79037d74c3c1bb4a8661fb608e8674b7e4260d6a3f8f51
#   Building wheel for typing (setup.py) ... done
#   Created wheel for typing: filename=typing-3.7.4.3-py3-none-any.whl size=26305 sha256=6c7517b8841f631ea194ece42b474094c834b00617d4bb1887e1d39666e4ad25
#   Stored in directory: /home/rafael/.cache/pip/wheels/9d/67/2f/53e3ef32ec48d11d7d60245255e2d71e908201d20c880c08ee
# Successfully built nvidia-ml-py3 typing
# WARNING: Skipping /home/rafael/anaconda3/lib/python3.11/site-packages/colorama-0.4.6.dist-info due to invalid metadata entry 'name'
# Installing collected packages: nvidia-ml-py3, cymem, wasabi, typing, typer, triton, spacy-loggers, spacy-legacy, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, murmurhash, langcodes, fastprogress, cloudpathlib, catalogue, blis, srsly, preshed, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, confection, weasel, torch, thinc, torchvision, spacy, fastai
# WARNING: Skipping /home/rafael/anaconda3/lib/python3.11/site-packages/colorama-0.4.6.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/rafael/anaconda3/lib/python3.11/site-packages/colorama-0.4.6.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/rafael/anaconda3/lib/python3.11/site-packages/colorama-0.4.6.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/rafael/anaconda3/lib/python3.11/site-packages/colorama-0.4.6.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/rafael/anaconda3/lib/python3.11/site-packages/colorama-0.4.6.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/rafael/anaconda3/lib/python3.11/site-packages/colorama-0.4.6.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/rafael/anaconda3/lib/python3.11/site-packages/colorama-0.4.6.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/rafael/anaconda3/lib/python3.11/site-packages/colorama-0.4.6.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/rafael/anaconda3/lib/python3.11/site-packages/colorama-0.4.6.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/rafael/anaconda3/lib/python3.11/site-packages/colorama-0.4.6.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /home/rafael/anaconda3/lib/python3.11/site-packages/colorama-0.4.6.dist-info due to invalid metadata entry 'name'
# Successfully installed blis-0.7.11 catalogue-2.0.10 cloudpathlib-0.16.0 confection-0.1.4 cymem-2.0.8 fastai-1.0.52 fastprogress-1.0.3 langcodes-3.3.0 murmurhash-1.0.10 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-ml-py3-7.352.0 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.1.105 preshed-3.0.9 spacy-3.7.4 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.4.8 thinc-8.2.3 torch-2.2.2 torchvision-0.17.2 triton-2.2.0 typer-0.9.4 typing-3.7.4.3 wasabi-1.1.2 weasel-0.3.4
# WARNING: Skipping /home/rafael/anaconda3/lib/python3.11/site-packages/colorama-0.4.6.dist-info due to invalid metadata entry 'name'
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 9
#       6 import fastai
#       8 from fastai import *
# ----> 9 from fastai.vision import *
#      11 # from torchvision.models import *
#      12 # import pretrainedmodels
#      14 from utils import *
#
# File ~/anaconda3/lib/python3.11/site-packages/fastai/vision/__init__.py:1
# ----> 1 from .. import basics
#       2 from ..basics import *
#       3 from .learner import *
#
# File ~/anaconda3/lib/python3.11/site-packages/fastai/basics.py:1
# ----> 1 from .basic_train import *
#       2 from .callback import *
#       3 from .core import *
#
# File ~/anaconda3/lib/python3.11/site-packages/fastai/basic_train.py:2
#       1 "Provides basic training and validation with `Learner`"
# ----> 2 from .torch_core import *
#       3 from .basic_data import *
#       4 from .callback import *
#
# File ~/anaconda3/lib/python3.11/site-packages/fastai/torch_core.py:2
#       1 "Utility functions to help deal with tensors"
# ----> 2 from .imports.torch import *
#       3 from .core import *
#       4 from collections import OrderedDict
#
# File ~/anaconda3/lib/python3.11/site-packages/fastai/imports/__init__.py:1
# ----> 1 from .core import *
#       2 from .torch import *
#
# File ~/anaconda3/lib/python3.11/site-packages/fastai/imports/core.py:9
#       6 import html, re, requests, tarfile, numbers, tempfile
#       8 from abc import abstractmethod, abstractproperty
# ----> 9 from collections import abc,  Counter, defaultdict, Iterable, namedtuple, OrderedDict
#      10 import concurrent
#      11 from concurrent.futures import ProcessPoolExecutor, ThreadPoolExecutor
#
# ImportError: cannot import name 'Iterable' from 'collections' (/home/rafael/anaconda3/lib/python3.11/collections/__init__.py)

# %%
path = os.path("../../../dados/06-flowers/")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 path = os.path("../../../dados/06-flowers/")
#
# TypeError: 'module' object is not callable

# %%
tfms = get_transforms(max_rotate= 10.,max_zoom=1., max_lighting=0.20, do_flip=False,
                      max_warp=0., xtra_tfms=[flip_lr(), brightness(change=(0.3, 0.60), p=0.7), contrast(scale=(0.5, 2), p=0.7),
                                              crop_pad(size=600, padding_mode='border', row_pct=0.,col_pct=0.),
                                              rand_zoom(scale=(1.,1.5)), rand_crop(),
                                              perspective_warp(magnitude=(-0.1,0.1)),
                                              symmetric_warp(magnitude=(-0.1,0.1)) ])

src = (ImageList.from_folder(path)
        .split_by_rand_pct(0.2, seed=42)
        .label_from_folder())
